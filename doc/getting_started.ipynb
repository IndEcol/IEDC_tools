# %% [markdown]
# # IEDC_tools Getting started
#
# A short walkhrough for the different functions in `IEDC_tools`.
#
# ## Preparatory steps
#
# - Get the `IEDC_pass.py` ready. For your convenience there is a template file `IEDC_pass_TEMPLATE.py` in the root folder.
# - Get the `IEDC_paths.py` ready. For your convenience there is a template file `IEDC_paths_TEMPLATE.py` in the root folder.
# - Create a Python environment that contains: pymysql, pandas, numpy

# %%
# Since this notebook is in a subfolder, we need to include the path

import sys
sys.path.insert(0,'..')

# %%
from IEDC_tools import dbio, file_io, validate

# The directory browsing is not yet fully implemented. 
# So far IEDC_tools works only on a single file basis.
# Therefore it is necessary to specify a file. The path is specified in `IEDC_paths.py`

candidate_file = 'test.xlsx'

# %% [markdown]
# ## Validation
#
# These are some simple validation functions.

# %%
# Get the file's classifications

class_names = validate.get_class_names(candidate_file)
class_names
# Out:
#          classification_id                 name attribute_no  \
# aspect_1            custom       origin_process       custom
# aspect_2            custom  destination_process       custom
# aspect_3            custom            commodity       custom
# aspect_4                 1              element            3
# aspect_5                 2               region            1
# aspect_6                 3                 time            1
#
#                                                 custom_name
# aspect_1  origin_process__1_F_steel_SankeyFlows_2008_Global
# aspect_2  destination_process__1_F_steel_SankeyFlows_200...
# aspect_3       commodity__1_F_steel_SankeyFlows_2008_Global
# aspect_4                                  chemical_elements
# aspect_5                                   regions_iso_iedc
# aspect_6                                               time

# %%
# Checks for the above classifications if they exists in the database,
#  i.e. classification_definition

validate.check_classification_definition(class_names, crash=False)
# Out:
# WARNING: 'origin_process__1_F_steel_SankeyFlows_2008_Global' already exists in the DB classification table. Adding it again may fail or create ambiguous values.
# WARNING: 'destination_process__1_F_steel_SankeyFlows_2008_Global' already exists in the DB classification table. Adding it again may fail or create ambiguous values.
# WARNING: 'commodity__1_F_steel_SankeyFlows_2008_Global' already exists in the DB classification table. Adding it again may fail or create ambiguous values.
# WARNING: 'chemical_elements' already exists in the DB classification table. Adding it again may fail or create ambiguous values.
# WARNING: 'regions_iso_iedc' already exists in the DB classification table. Adding it again may fail or create ambiguous values.
# WARNING: 'time' already exists in the DB classification table. Adding it again may fail or create ambiguous values.
# [True, True, True, True, True, True]

# %%
# To check if the attributes are in the DB,
#  we need to load the data (Value_Master) first

file_data = file_io.read_candidate_data(candidate_file)
file_data.head()
# Out:
#              origin_process   destination_process           commodity element  \
# 0  End-of-life scrap market      Scrap separation  Postconsumer scrap      Fe
# 1           Iron ore market      Direct reduction            Iron ore      Fe
# 2          Direct reduction                  Loss         Iron losses      Fe
# 3          Direct reduction      Electric furnace                 DRI      Fe
# 4          Electric furnace  Secondary metallurgy        Liquid steel      Fe
#
#    region  time  value unit nominator unit denominator stats_array string  \
# 0  Global  2008  290.0             Mt               yr               none
# 1  Global  2008   66.3             Mt               yr               none
# 2  Global  2008    0.5             Mt               yr               none
# 3  Global  2008   65.8             Mt               yr               none
# 4  Global  2008  410.3             Mt               yr               none
#
#   comment
# 0    none
# 1    none
# 2    none
# 3    none
# 4    none

# %%
# Checks in classification_items if a. the classification_ids exists and
#  b. an attribute exist

validate.check_classification_items(class_names, file_data, crash=False)
# Out:
# WARNING: classification_id '48' already exists in the table classification_items. Adding its attributes again may fail or create ambiguous values.
# WARNING: 'End-of-life scrap market' already in classification_items
# WARNING: 'Iron ore market' already in classification_items
# WARNING: 'Direct reduction' already in classification_items
# WARNING: 'Electric furnace' already in classification_items
# WARNING: 'Secondary metallurgy' already in classification_items
# WARNING: 'CC bloom' already in classification_items
# WARNING: 'CC billet' already in classification_items
# WARNING: 'CC slab' already in classification_items
# WARNING: 'Ingot casting' already in classification_items
# WARNING: 'Steel product casting (SPC)' already in classification_items
# WARNING: 'Blast furncace' already in classification_items
# WARNING: 'Market for End-of-life scrap' already in classification_items
# WARNING: 'Market for Forming scrap' already in classification_items
# WARNING: 'Market for Fabrication scrap' already in classification_items
# WARNING: 'Scrap preparation' already in classification_items
# WARNING: 'Foundary iron casting' already in classification_items
# WARNING: 'Oxygen blown converter' already in classification_items
# WARNING: 'Open heath furnace' already in classification_items
# WARNING: 'Primary Mill' already in classification_items
# WARNING: 'Section Mill' already in classification_items
# WARNING: 'Rod + Bar Mill' already in classification_items
# WARNING: 'Plate Mill' already in classification_items
# WARNING: 'Hot Strip Mill' already in classification_items
# WARNING: 'Seamless tube plant' already in classification_items
# WARNING: 'Tube welding plant' already in classification_items
# WARNING: 'Cold Rolling Mill' already in classification_items
# WARNING: 'Galvanising plant' already in classification_items
# WARNING: 'Tinmill' already in classification_items
# WARNING: 'Organic coating plant' already in classification_items
# WARNING: 'Market for Light Sections' already in classification_items
# WARNING: 'Market for Heavy Sections' already in classification_items
# WARNING: 'Market for Rail' already in classification_items
# WARNING: 'Market for Reinforcing bar' already in classification_items
# WARNING: 'Market for Wire rod' already in classification_items
# WARNING: 'Market for Hot rolled bar' already in classification_items
# WARNING: 'Market for Plate' already in classification_items
# WARNING: 'Market for Hot rolled coil (HRC)' already in classification_items
# WARNING: 'Market for HRC galvanised' already in classification_items
# WARNING: 'Market for HR narrow strip' already in classification_items
# WARNING: 'Market for Cold rolled coil (CRC)' already in classification_items
# WARNING: 'Market for CRC galvanised' already in classification_items
# WARNING: 'Market for CRC organic coated' already in classification_items
# WARNING: 'Market for CRC tinned' already in classification_items
# WARNING: 'Market for Electrical sheet' already in classification_items
# WARNING: 'Market for Welded tube' already in classification_items
# WARNING: 'Market for Seamless tube' already in classification_items
# WARNING: 'Market for Cast iron products' already in classification_items
# WARNING: 'Market for Cast steel products' already in classification_items
# WARNING: 'Buildings' already in classification_items
# WARNING: 'Infrastructure' already in classification_items
# WARNING: 'Mechanical equipment' already in classification_items
# WARNING: 'Cars' already in classification_items
# WARNING: 'Trucks' already in classification_items
# WARNING: 'Ships + other' already in classification_items
# WARNING: 'Electrical equipment' already in classification_items
# WARNING: 'Metal goods' already in classification_items
# WARNING: 'Domestic appliances' already in classification_items
# WARNING: 'Food packaging' already in classification_items
# WARNING: classification_id '49' already exists in the table classification_items. Adding its attributes again may fail or create ambiguous values.
# WARNING: 'Scrap separation' already in classification_items
# WARNING: 'Direct reduction' already in classification_items
# WARNING: 'Loss' already in classification_items
# WARNING: 'Electric furnace' already in classification_items
# WARNING: 'Secondary metallurgy' already in classification_items
# WARNING: 'CC bloom' already in classification_items
# WARNING: 'CC billet' already in classification_items
# WARNING: 'Ingot casting' already in classification_items
# WARNING: 'Steel product casting (SPC)' already in classification_items
# WARNING: 'CC slab' already in classification_items
# WARNING: 'Market for Scrap' already in classification_items
# WARNING: 'Section Mill' already in classification_items
# WARNING: 'Rod + Bar Mill' already in classification_items
# WARNING: 'Hot Strip Mill' already in classification_items
# WARNING: 'Plate Mill' already in classification_items
# WARNING: 'Primary Mill' already in classification_items
# WARNING: 'Market for Cast steel products' already in classification_items
# WARNING: 'Blast furnace' already in classification_items
# WARNING: 'Oxygen blown converter ' already in classification_items
# WARNING: 'Open heath furnace' already in classification_items
# WARNING: 'Foundary iron casting' already in classification_items
# WARNING: 'Scrap preparation' already in classification_items
# WARNING: 'Market for Scrap iron and additives' already in classification_items
# WARNING: 'Market for Cast iron products' already in classification_items
# WARNING: 'Market for Light sections' already in classification_items
# WARNING: 'Market for Heavy sections' already in classification_items
# WARNING: 'Market for Rail' already in classification_items
# WARNING: 'Seamless tube plant' already in classification_items
# WARNING: 'Market for Reinforcing bar' already in classification_items
# WARNING: 'Market for Wire rod' already in classification_items
# WARNING: 'Market for HR bar' already in classification_items
# WARNING: 'Market for Plate' already in classification_items
# WARNING: 'Tube welding plant' already in classification_items
# WARNING: 'Cold Rolling Mill' already in classification_items
# WARNING: 'Galvanising plant' already in classification_items
# WARNING: 'Market for Hot rolled coil' already in classification_items
# WARNING: 'Market for HR Narrow strip' already in classification_items
# WARNING: 'Market for Seamless tube' already in classification_items
# WARNING: 'Market for Wielded tube' already in classification_items
# WARNING: 'Market for Electrical sheet' already in classification_items
# WARNING: 'Market for Cold rolled coil' already in classification_items
# WARNING: 'Tinmill' already in classification_items
# WARNING: 'Market for CRC galvanised' already in classification_items
# WARNING: 'Organic coating plant' already in classification_items
# WARNING: 'Market for HRC galvanised' already in classification_items
# WARNING: 'Market for CRC tinned' already in classification_items
# WARNING: 'Market for CRC organic coated' already in classification_items
# WARNING: 'Buildings' already in classification_items
# WARNING: 'Infrastructure' already in classification_items
# WARNING: 'Mechanical equipment' already in classification_items
# WARNING: 'Cars' already in classification_items
# WARNING: 'Trucks' already in classification_items
# WARNING: 'Ships + other' already in classification_items
# WARNING: 'Electrical equipment' already in classification_items
# WARNING: 'Metal goods' already in classification_items
# WARNING: 'Domestic appliances' already in classification_items
# WARNING: 'Food packaging' already in classification_items
# WARNING: 'Market for Buildings' already in classification_items
# WARNING: 'Market for Infrastructure' already in classification_items
# WARNING: 'Market for Mechanical equipment' already in classification_items
# WARNING: 'Loss ' already in classification_items
# WARNING: 'Market for Cars' already in classification_items
# WARNING: 'Market for Trucks' already in classification_items
# WARNING: 'Market for Ships + other' already in classification_items
# WARNING: 'Market for Electrical equipment' already in classification_items
# WARNING: 'Market for Metal goods' already in classification_items
# WARNING: 'Market for Domestic appliances' already in classification_items
# WARNING: 'Market for Food packaging' already in classification_items
# WARNING: classification_id '50' already exists in the table classification_items. Adding its attributes again may fail or create ambiguous values.
# WARNING: 'Postconsumer scrap' already in classification_items
# WARNING: 'Iron ore' already in classification_items
# WARNING: 'Iron losses' already in classification_items
# WARNING: 'DRI' already in classification_items
# WARNING: 'Liquid steel' already in classification_items
# WARNING: 'Loss in form of slag' already in classification_items
# WARNING: 'Liquid steel (EF)' already in classification_items
# WARNING: 'Liquid steel (OBC)' already in classification_items
# WARNING: 'Liquid steel (OHF)' already in classification_items
# WARNING: 'Scrap (int. recycle)' already in classification_items
# WARNING: 'Loss in form of scale (mainly FeO)' already in classification_items
# WARNING: 'Scrap' already in classification_items
# WARNING: 'CC bloom' already in classification_items
# WARNING: 'CC billet' already in classification_items
# WARNING: 'CC slab' already in classification_items
# WARNING: 'Ingot' already in classification_items
# WARNING: 'Cast steel products' already in classification_items
# WARNING: 'Pig iron' already in classification_items
# WARNING: 'Foundary iron' already in classification_items
# WARNING: 'End-of-life scrap' already in classification_items
# WARNING: 'Forming scrap' already in classification_items
# WARNING: 'Fabrication scrap' already in classification_items
# WARNING: 'Scrap ' already in classification_items
# WARNING: 'Scrap steel' already in classification_items
# WARNING: 'Scrap iron and additives' already in classification_items
# WARNING: 'Cast iron products' already in classification_items
# WARNING: 'Bloom/billet/slab' already in classification_items
# WARNING: 'Light sections' already in classification_items
# WARNING: 'Heavy sections' already in classification_items
# WARNING: 'Rail' already in classification_items
# WARNING: 'Rod/bar' already in classification_items
# WARNING: 'Reinforcing bar' already in classification_items
# WARNING: 'Wire rod' already in classification_items
# WARNING: 'HR bar' already in classification_items
# WARNING: 'Plate' already in classification_items
# WARNING: 'Hot rolled coil' already in classification_items
# WARNING: 'Seamless tube' already in classification_items
# WARNING: 'Welded tube' already in classification_items
# WARNING: 'Cold rolled coil' already in classification_items
# WARNING: 'Electrical sheet' already in classification_items
# WARNING: 'CRC galvanised' already in classification_items
# WARNING: 'HRC galvanised' already in classification_items
# WARNING: 'CRC tinned' already in classification_items
# WARNING: 'CRC organic coated' already in classification_items
# WARNING: 'Hot rolled bar' already in classification_items
# WARNING: 'Hot rolled coil (HRC)' already in classification_items
# WARNING: 'HR narrow strip' already in classification_items
# WARNING: 'Cold rolled coil (CRC)' already in classification_items
# WARNING: 'Loss of Light sections' already in classification_items
# WARNING: 'Loss of Heavy sections' already in classification_items
# WARNING: 'Loss of Reinforcing bar' already in classification_items
# WARNING: 'Loss of Wire rod' already in classification_items
# WARNING: 'Loss of Hot rolled bar' already in classification_items
# WARNING: 'Loss of Plate' already in classification_items
# WARNING: 'Loss of Hot rolled coil (HRC)' already in classification_items
# WARNING: 'Loss of HRC galvanised' already in classification_items
# WARNING: 'Loss of HR narrow strip' already in classification_items
# WARNING: 'Loss of Cold rolled coil (CRC)' already in classification_items
# WARNING: 'Loss of CRC galvanised' already in classification_items
# WARNING: 'Loss of CRC organic coated' already in classification_items
# WARNING: 'Loss of CRC tinned' already in classification_items
# WARNING: 'Loss of Electrical sheet' already in classification_items
# WARNING: 'Loss of Welded tube' already in classification_items
# WARNING: 'Loss of Seamless tube' already in classification_items
# WARNING: classification_id '1' already exists in the table classification_items. Adding its attributes again may fail or create ambiguous values.
# WARNING: 'Fe' already in classification_items
# WARNING: classification_id '2' already exists in the table classification_items. Adding its attributes again may fail or create ambiguous values.
# WARNING: 'Global' already in classification_items
# WARNING: classification_id '3' already exists in the table classification_items. Adding its attributes again may fail or create ambiguous values.
# WARNING: '2008' already in classification_items
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %% [markdown]
# # Writing to the Database
#
# To some more exciting features...
#
# ***In order to make the following functions work, the classification and attributes must be deleted from the tables `calssification_definitions` and `classification_items` first.*** That means they will only work if the two checks above ran without warning. I will have to:
#
# ```sql
# DELETE FROM iedc_review.classification_definition WHERE id IN (48, 49, 50);
# DELETE FROM iedc_review.classification_items WHERE classification_id IN (48, 49, 50);
# ```
#
# The `id`s 48, 49, 50 were named above.

# %%
# This will create the classifications in the `classification_definitions` table
# For demonstration purposes, I will *now* delete classification_ids and attributes
#  that appeared as warnings above.

validate.create_db_class_defs(candidate_file)
# Out:
# Wrote custom classification 'origin_process__1_F_steel_SankeyFlows_2008_Global' to classification_definitions
# Wrote custom classification 'destination_process__1_F_steel_SankeyFlows_2008_Global' to classification_definitions
# Wrote custom classification 'commodity__1_F_steel_SankeyFlows_2008_Global' to classification_definitions

# %%
# Writes the attributes of a custom classification to the database `classification_items`

validate.create_db_class_items(candidate_file)
# Out:
# Wrote attributes for custom classification '51' to classification_items
# Wrote attributes for custom classification '52' to classification_items
# Wrote attributes for custom classification '53' to classification_items

# %%
# Add a the contributor to the `users` table, if not known yet

validate.add_user(candidate_file)
# Out:
# User 'Stefan Pauliuk' already exists in db table users

# %%
# Add a licence to the `licences` table, if not known yet

validate.add_license(candidate_file)
# Out:
# Licence 'MIT' already exists in db table 'licences'

# %% [markdown]
# ### Data upload
#
# Finally it is time to upload the data to the `data` table. **To make this work, the `data` table must not contain values for this dataset_id yet**
# For demonstration purposes, I will delete the values in question:
#
# ```sql
# DELETE FROM iedc_review.data WHERE dataset_id = 1;
# ```
#
# *The script should also fail if there is a value in the `datasets` table, but we need to figure out who creates that table, first.* Therefore `crash=False` for now.

# %%
# Finally it is time to upload the data to the `data` table
# **To make this work, the `data` table must not contain values for this dataset_id yet**
# For demonstration purposes, I will delete all values 

validate.upload_data(candidate_file, crash=False)
# Out:
# WARNING: The database already contains values for dataset_id '1'
# Wrote data for '1_F_steel_SankeyFlows_2008_Global'

# %% [markdown]
# That's it for now...
